# %% [markdown]
# # Posterior Estimation for SIR-like Models
#
# _Author: Stefan T. Radev_

# %%
import datetime

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

import keras

# For BayesFlow devs: this ensures that the latest dev version can be found
import sys
sys.path.append('../')

import bayesflow as bf

# %% [markdown]
# ## Introduction <a class="anchor" id="introduction"></a>
#
# In this tutorial, we will illustrate how to perform posterior inference on simple, stationary SIR-like models (complex models will be tackled in a further notebook). SIR-like models comprise suitable illustrative examples, since they generate time-series and their outputs represent the results of solving a system of ordinary differential equations (ODEs).
#
# The details for tackling stochastic epidemiological models with neural networks are described in our corresponding paper, which you can consult for a more formal exposition and a more comprehensive treatment of neural architectures:
#
# <em>OutbreakFlow: Model-based Bayesian inference of disease outbreak dynamics with invertible neural networks and its application to the COVID-19 pandemics in Germany</em> https://journals.plos.org/ploscompbiol/article?id=10.1371/journal.pcbi.1009472

# %% [markdown]
# ## Defining the Simulator <a class="anchor" id="defining_the_generative"></a>

# %%
RNG = np.random.default_rng(2024)

# %% [markdown]
# As described in our [very first notebook](Intro_Amortized_Posterior_Estimation.ipynb), a generative model consists of a prior (encoding suitable parameter ranges) and a simulator (generating data given simulations). Our underlying model distinguishes between susceptible, $S$, infected, $I$, and recovered, $R$, individuals with infection and recovery occurring at a constant transmission rate $\lambda$ and constant recovery rate $\mu$, respectively. The model dynamics are governed by the following system of ODEs:
#
# $$
# \begin{align}
#     \frac{dS}{dt} &= -\lambda\,\left(\frac{S\,I}{N}\right) \\
#     \frac{dI}{dt} &= \lambda\,\left(\frac{S\,I}{N}\right) - \mu\,I \\
#     \frac{dR}{dt} &= \mu\,I,
# \end{align}
# $$
#
# with $N = S + I + R$ denoting the total population size. For the purpose of forward inference (simulation), we will use a time step of $dt = 1$, corresponding to daily case reports. In addition to the ODE parameters $\lambda$ and $\mu$, we consider a reporting delay parameter $L$ and a dispersion parameter $\psi$, which affect the number of reported infected individuals via a negative binomial disttribution (https://en.wikipedia.org/wiki/Negative_binomial_distribution):
#
# $$
# \begin{equation}
#     I_t^{(obs)} \sim \textrm{NegBinomial}(I^{(new)}_{t-L}, \psi),
# \end{equation}
# $$
#
# In this way, we connect the latent disease model to an observation model, which renders the relationship between parameters and data a stochastic one. Note, that the observation model induces a further parameter $\psi$, responsible for the dispersion of the noise.
# Finally, we will also treat the number of initially infected individuals, $I_0$ as an unknown parameter (having its own prior distribution).

# %% [markdown]
# ### Prior <a class="anchor" id="prior"></a>

# %% [markdown]
# We will place the following prior distributions over the five model parameters, summarized in the table below:
#
# $$
# \begin{aligned}
# & \text {Table 1. Description of model parameters and corresponding prior distributions}\\
# &\begin{array}{lcl}
# \hline \hline \text { Description} & \text { Symbol } & \text { Prior Distribution } \\
# \hline \hline \text{Initial transmission rate} & \text{$\lambda$} & \text{$\textrm{LogNormal}(\log(0.4), 0.5)$} \\
# \text{Recovery rate of infected individuals} & \text{$\mu$} & \text{$\textrm{LogNormal}(\log(1/8), 0.2)$} \\
# \text{Reporting delay (lag)} & \text{$L$} & \text{$\textrm{LogNormal}(\log(8), 0.2)$} \\
# \text{Number of initially infected individuals} & \text{$I_0$} & \text{$\textrm{Gamma}(2, 20)$} \\
# \text{Dispersion of the negative binomial distribution} & \text{$\psi$} & \text{$\textrm{Exponential}(5)$} \\
# \hline
# \end{array}
# \end{aligned}
# $$
#
# How did we come up with these priors? In this case, we rely on the domain expertise and previous research  (https://www.science.org/doi/10.1126/science.abb9789). In addition, the new parameter $\psi$ follows an exponential distribution, which restricts it to positive numbers. Below is the implementation of these priors:

# %%
def prior():
    """Generates a random draw from the joint prior."""

    lambd = RNG.lognormal(mean=np.log(0.4), sigma=0.5)
    mu = RNG.lognormal(mean=np.log(1 / 8), sigma=0.2)
    D = RNG.lognormal(mean=np.log(8), sigma=0.2)
    I0 = RNG.gamma(shape=2, scale=20)
    psi = RNG.exponential(5)
    return {"lambd": lambd, "mu": mu, "D": D, "I0": I0, "psi": psi}

# %% [markdown]
# ### Observation Model (Implicit Likelihood Function) <a class="anchor" id="simulator__implicit_likelihood"></a>

# %%
from scipy.stats import nbinom


def convert_params(mu, phi):
    """Helper function to convert mean/dispersion parameterization of a negative binomial to N and p,
    as expected by numpy's negative_binomial.

    See https://en.wikipedia.org/wiki/Negative_binomial_distribution#Alternative_formulations
    """

    r = phi
    var = mu + 1 / r * mu**2
    p = (var - mu) / var
    return r, 1 - p


def stationary_SIR(lambd, mu, D, I0, psi, N=83e6, T=14, eps=1e-5):
    """Performs a forward simulation from the stationary SIR model given a random draw from the prior."""

    # Extract parameters and round I0 and D
    I0 = np.ceil(I0)
    D = int(round(D))

    # Initial conditions
    S, I, R = [N - I0], [I0], [0]

    # Reported new cases
    C = [I0]

    # Simulate T-1 timesteps
    for t in range(1, T + D):
        # Calculate new cases
        I_new = lambd * (I[-1] * S[-1] / N)

        # SIR equations
        S_t = S[-1] - I_new
        I_t = np.clip(I[-1] + I_new - mu * I[-1], 0.0, N)
        R_t = np.clip(R[-1] + mu * I[-1], 0.0, N)

        # Track
        S.append(S_t)
        I.append(I_t)
        R.append(R_t)
        C.append(I_new)

    reparam = convert_params(np.clip(np.array(C[D:]), 0, N) + eps, psi)
    C_obs = RNG.negative_binomial(reparam[0], reparam[1])
    return dict(cases=C_obs[:, np.newaxis])

# %% [markdown]
# As you can see, in addition to the parameters, our simulator requires two further arguments: the total population size $N$ and the time horizon $T$. These are quantities over which we can amortize (i.e., context variables), but for this example, we will just use the population of Germany and the first two weeks of the pandemics (i.e., $T=14$), in the same vein as https://www.science.org/doi/10.1126/science.abb9789.

# %% [markdown]
# ### Loading Real Data <a class="anchor" id="loading_real_data"></a>
#
# We will define a simple helper function to load the actually reported cases in 2020 for the first two weeks of the Covid-19 pandemic in Germany.

# %%
def load_data():
    """Helper function to load cumulative cases and transform them to new cases."""

    confirmed_cases_url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv"
    confirmed_cases = pd.read_csv(confirmed_cases_url, sep=",")

    date_data_begin = datetime.date(2020, 3, 1)
    date_data_end = datetime.date(2020, 3, 15)
    format_date = lambda date_py: f"{date_py.month}/{date_py.day}/{str(date_py.year)[2:4]}"
    date_formatted_begin = format_date(date_data_begin)
    date_formatted_end = format_date(date_data_end)

    cases_obs = np.array(
        confirmed_cases.loc[confirmed_cases["Country/Region"] == "Germany", date_formatted_begin:date_formatted_end]
    )[0]
    new_cases_obs = np.diff(cases_obs)
    return new_cases_obs

# %% [markdown]
# ### Stitiching Things Together <a class="anchor" id="generative_model"></a>
# We can combine the prior $p(\theta)$ and the observation model $p(x_{1:T}\mid\theta)$ into a joint model $p(\theta, x_{1:T}) = p(\theta) \; p(x_{1:T}\mid\theta)$ using the `make_simulator` builder.
# The resulting object can now generate *batches* of simulations.

# %%
simulator = bf.make_simulator([prior, stationary_SIR])

# %%
# %%time
test_sims = simulator.sample(batch_size=2)
print(test_sims["lambd"].shape)
print(test_sims["D"].shape)
print(test_sims["cases"].shape)
# Out:
# (2, 1)
# (2, 1)
# (2, 14, 1)
# CPU times: total: 0 ns
# Wall time: 1e+03 µs

# %% [markdown]
# ## Prior Checking <a class="anchor" id="prior_checking"></a>
#
# Any principled Bayesian workflow requires some prior predictive or prior pushforward checks to ensure that the prior specification is consistent with domain expertise (see https://betanalpha.github.io/assets/case_studies/principled_bayesian_workflow.html). The BayesFlow library provides some rudimentary visual tools for performing prior checking. For instance, we can visually inspect the joint prior in the form of bivariate plots. We can focus on particular parameter combinations, such as $\lambda$, $\mu$, and $D$:

# %%
prior_samples = simulator.simulators[0].sample(1000)

subset = {
    "lambda": prior_samples["lambd"],
    "mu": prior_samples["mu"],
    "D": prior_samples["D"]
}

grid = bf.diagnostics.plots.pairs_samples(subset)
# Out:
# c:\Users\radevs\AppData\Local\anaconda3\envs\bf\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Defining the Adapter
#
# We need to ensure that the outputs of the forward model are suitable for processing with neural networks. Currently, they are not, since our data $x_{1:T}$ consists of large integer (count) values. However, neural networks like scaled data. Furthermore, our parameters $\theta$ exhibit widely different scales due to their prior specification and role in the simulator. Finally, BayesFlow needs to know which variables are to be inferred and which ones are to be processed by the summary network before being passed to the inference network. We handle all of these steps using an `Adapter`.
#
# Since all of our parameters and observables can only take on positive values, we will apply a log plus one transform to all quantities. Note, that `BayesFlow` expects the following keys to be present in the final outputs of your configured simulations:
# - `inference_variables`: These are the variables we are inferring.
# - `summary_variables`: These are the variables that are compressed throgh a summary network and used for inferring the inference variables.
#
# Thus, what our approximators are learning is $p(\text{inference\_variables} \mid t(\text{summary\_variables}))$, where $t$ is the summary network.

# %%
adapter = (
    bf.adapters.Adapter()
    .convert_dtype("float64", "float32")
    # since all our variables are non-negative (zero or larger)
    # this .apply call ensures that the variables are transformed
    # to the unconstrained real space
    .apply(forward=lambda x: np.log1p(x), inverse=lambda x: np.expm1(x))
    .concatenate(["lambd", "mu", "D", "I0", "psi"], into="inference_variables")
    .rename("cases", "summary_variables")
)

# %% [markdown]
# ## Defining the Neural Approximator <a class="anchor" id="defining_the_neural"></a>
#
# We can now proceed to define our `BayesFlow` neural architecture, that is, combine a summary network with an inference network.

# %% [markdown]
# ### Summary Network <a class="anchor" id="summary_network"></a>
#
# Since our simulator outputs 3D tensors of shape ``(batch_size, T = 14, 1)``, we need to reduce this three-dimensional tensor into a two-dimensional tensor of shape ``(batch_size, summary_dim)``. Our model outputs are actually so simple that we could have just removed the trailing dimension of the raw outputs and simply fed the data directly to the inference network.
#
# However, we demonstrate the use of a simple Gated Recurrent Unit (GRU) summary network. Any `keras` model can interact with `BayesFlow` by inherting from `SummaryNetwork` which accepts an addition `stage` argument indicating the mode the network is currently operating in (i.e., `training` vs. `inference`).

# %%
class GRU(bf.networks.SummaryNetwork):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

        self.gru = keras.layers.GRU(64, dropout=0.1)
        self.summary_stats = keras.layers.Dense(8)
        
    def call(self, time_series, **kwargs):
        """Compresses time_series of shape (batch_size, T, 1) into summaries of shape (batch_size, 8)."""

        summary = self.gru(time_series, training=kwargs.get("stage") == "training")
        summary = self.summary_stats(summary)
        return summary

# %%
summary_net = GRU()

# %% [markdown]
# ### Inference Network

# %% [markdown]
# As inference network we choose a flow matching architecture with some dropout to robustify the inference. Dropout is primarily important when learning from a (small) offline dataset. See below for details.

# %%
inference_net = bf.networks.FlowMatching(
    subnet_kwargs={"residual": True, "dropout": 0.1, "widths": (128, 128, 128)}
)

# %%
workflow = bf.BasicWorkflow(
    simulator=simulator,
    adapter=adapter,
    inference_network=inference_net,
    summary_network=summary_net,
    inference_variables=["lambd", "mu", "D", "I0", "psi"]
)

# %% [markdown]
# ## Training <a class="anchor" id="training"></a>
#
# Ready to train! Since our simulator is pretty fast, we can safely go with online training. Let's glean the time taken for a batch of $32$ simulations.

# %%
# %%time
_ = simulator.sample(32)
# Out:
# CPU times: total: 0 ns
# Wall time: 7.51 ms

# %% [markdown]
# Not too bad! However, for the purpose of illustration, we will go with offline training using a fixed data set of simulations.

# %% [markdown]
# ### Generating Offline Data <a class="anchor" id="generating_offline_data"></a>

# %%
training_data = simulator.sample(5000)

validation_data = simulator.sample(300)

# %% [markdown]
# We are not ready to train. If nto provided, the default settings use $100$ epochs with a batch size of $32$ are used.

# %%
history = workflow.fit_offline(training_data, epochs=300, batch_size=64, validation_data=validation_data)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OfflineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 1.2895 - loss/inference_loss: 1.2895 - val_loss: 0.7265 - val_loss/inference_loss: 0.7265
# Epoch 2/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7152 - loss/inference_loss: 0.7152 - val_loss: 0.7053 - val_loss/inference_loss: 0.7053
# Epoch 3/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6590 - loss/inference_loss: 0.6590 - val_loss: 0.6527 - val_loss/inference_loss: 0.6527
# Epoch 4/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6248 - loss/inference_loss: 0.6248 - val_loss: 0.8274 - val_loss/inference_loss: 0.8274
# Epoch 5/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6142 - loss/inference_loss: 0.6142 - val_loss: 0.5050 - val_loss/inference_loss: 0.5050
# Epoch 6/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6067 - loss/inference_loss: 0.6067 - val_loss: 0.6223 - val_loss/inference_loss: 0.6223
# Epoch 7/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5991 - loss/inference_loss: 0.5991 - val_loss: 0.6421 - val_loss/inference_loss: 0.6421
# Epoch 8/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5604 - loss/inference_loss: 0.5604 - val_loss: 0.4576 - val_loss/inference_loss: 0.4576
# Epoch 9/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5670 - loss/inference_loss: 0.5670 - val_loss: 0.5685 - val_loss/inference_loss: 0.5685
# Epoch 10/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5514 - loss/inference_loss: 0.5514 - val_loss: 0.5969 - val_loss/inference_loss: 0.5969
# Epoch 11/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5439 - loss/inference_loss: 0.5439 - val_loss: 0.5828 - val_loss/inference_loss: 0.5828
# Epoch 12/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5203 - loss/inference_loss: 0.5203 - val_loss: 0.5399 - val_loss/inference_loss: 0.5399
# Epoch 13/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5128 - loss/inference_loss: 0.5128 - val_loss: 0.5315 - val_loss/inference_loss: 0.5315
# Epoch 14/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5019 - loss/inference_loss: 0.5019 - val_loss: 0.4709 - val_loss/inference_loss: 0.4709
# Epoch 15/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4920 - loss/inference_loss: 0.4920 - val_loss: 0.5106 - val_loss/inference_loss: 0.5106
# Epoch 16/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4695 - loss/inference_loss: 0.4695 - val_loss: 0.4536 - val_loss/inference_loss: 0.4536
# Epoch 17/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4850 - loss/inference_loss: 0.4850 - val_loss: 0.4478 - val_loss/inference_loss: 0.4478
# Epoch 18/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4659 - loss/inference_loss: 0.4659 - val_loss: 0.4673 - val_loss/inference_loss: 0.4673
# Epoch 19/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4640 - loss/inference_loss: 0.4640 - val_loss: 0.4654 - val_loss/inference_loss: 0.4654
# Epoch 20/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4553 - loss/inference_loss: 0.4553 - val_loss: 0.4836 - val_loss/inference_loss: 0.4836
# Epoch 21/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4644 - loss/inference_loss: 0.4644 - val_loss: 0.3998 - val_loss/inference_loss: 0.3998
# Epoch 22/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4389 - loss/inference_loss: 0.4389 - val_loss: 0.4631 - val_loss/inference_loss: 0.4631
# Epoch 23/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4561 - loss/inference_loss: 0.4561 - val_loss: 0.4036 - val_loss/inference_loss: 0.4036
# Epoch 24/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4261 - loss/inference_loss: 0.4261 - val_loss: 0.4040 - val_loss/inference_loss: 0.4040
# Epoch 25/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4323 - loss/inference_loss: 0.4323 - val_loss: 0.6834 - val_loss/inference_loss: 0.6834
# Epoch 26/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4438 - loss/inference_loss: 0.4438 - val_loss: 0.5092 - val_loss/inference_loss: 0.5092
# Epoch 27/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4318 - loss/inference_loss: 0.4318 - val_loss: 0.4712 - val_loss/inference_loss: 0.4712
# Epoch 28/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4330 - loss/inference_loss: 0.4330 - val_loss: 0.4597 - val_loss/inference_loss: 0.4597
# Epoch 29/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4192 - loss/inference_loss: 0.4192 - val_loss: 0.4055 - val_loss/inference_loss: 0.4055
# Epoch 30/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4095 - loss/inference_loss: 0.4095 - val_loss: 0.4288 - val_loss/inference_loss: 0.4288
# Epoch 31/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4389 - loss/inference_loss: 0.4389 - val_loss: 0.3676 - val_loss/inference_loss: 0.3676
# Epoch 32/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4287 - loss/inference_loss: 0.4287 - val_loss: 0.3774 - val_loss/inference_loss: 0.3774
# Epoch 33/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3955 - loss/inference_loss: 0.3955 - val_loss: 0.3717 - val_loss/inference_loss: 0.3717
# Epoch 34/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4223 - loss/inference_loss: 0.4223 - val_loss: 0.3070 - val_loss/inference_loss: 0.3070
# Epoch 35/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4151 - loss/inference_loss: 0.4151 - val_loss: 0.3385 - val_loss/inference_loss: 0.3385
# Epoch 36/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4006 - loss/inference_loss: 0.4006 - val_loss: 0.4250 - val_loss/inference_loss: 0.4250
# Epoch 37/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4105 - loss/inference_loss: 0.4105 - val_loss: 0.4481 - val_loss/inference_loss: 0.4481
# Epoch 38/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4036 - loss/inference_loss: 0.4036 - val_loss: 0.3674 - val_loss/inference_loss: 0.3674
# Epoch 39/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4071 - loss/inference_loss: 0.4071 - val_loss: 0.4327 - val_loss/inference_loss: 0.4327
# Epoch 40/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4127 - loss/inference_loss: 0.4127 - val_loss: 0.5144 - val_loss/inference_loss: 0.5144
# Epoch 41/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4054 - loss/inference_loss: 0.4054 - val_loss: 0.4557 - val_loss/inference_loss: 0.4557
# Epoch 42/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4001 - loss/inference_loss: 0.4001 - val_loss: 0.3192 - val_loss/inference_loss: 0.3192
# Epoch 43/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4083 - loss/inference_loss: 0.4083 - val_loss: 0.3338 - val_loss/inference_loss: 0.3338
# Epoch 44/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3884 - loss/inference_loss: 0.3884 - val_loss: 0.3447 - val_loss/inference_loss: 0.3447
# Epoch 45/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3921 - loss/inference_loss: 0.3921 - val_loss: 0.4415 - val_loss/inference_loss: 0.4415
# Epoch 46/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4136 - loss/inference_loss: 0.4136 - val_loss: 0.4668 - val_loss/inference_loss: 0.4668
# Epoch 47/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4021 - loss/inference_loss: 0.4021 - val_loss: 0.3978 - val_loss/inference_loss: 0.3978
# Epoch 48/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3933 - loss/inference_loss: 0.3933 - val_loss: 0.3994 - val_loss/inference_loss: 0.3994
# Epoch 49/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4024 - loss/inference_loss: 0.4024 - val_loss: 0.4070 - val_loss/inference_loss: 0.4070
# Epoch 50/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3972 - loss/inference_loss: 0.3972 - val_loss: 0.3494 - val_loss/inference_loss: 0.3494
# Epoch 51/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4035 - loss/inference_loss: 0.4035 - val_loss: 0.3404 - val_loss/inference_loss: 0.3404
# Epoch 52/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3850 - loss/inference_loss: 0.3850 - val_loss: 0.3658 - val_loss/inference_loss: 0.3658
# Epoch 53/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3789 - loss/inference_loss: 0.3789 - val_loss: 0.4789 - val_loss/inference_loss: 0.4789
# Epoch 54/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3860 - loss/inference_loss: 0.3860 - val_loss: 0.4344 - val_loss/inference_loss: 0.4344
# Epoch 55/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4047 - loss/inference_loss: 0.4047 - val_loss: 0.3886 - val_loss/inference_loss: 0.3886
# Epoch 56/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3917 - loss/inference_loss: 0.3917 - val_loss: 0.4174 - val_loss/inference_loss: 0.4174
# Epoch 57/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3887 - loss/inference_loss: 0.3887 - val_loss: 0.3633 - val_loss/inference_loss: 0.3633
# Epoch 58/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3931 - loss/inference_loss: 0.3931 - val_loss: 0.4381 - val_loss/inference_loss: 0.4381
# Epoch 59/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4097 - loss/inference_loss: 0.4097 - val_loss: 0.5430 - val_loss/inference_loss: 0.5430
# Epoch 60/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3884 - loss/inference_loss: 0.3884 - val_loss: 0.4650 - val_loss/inference_loss: 0.4650
# Epoch 61/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3856 - loss/inference_loss: 0.3856 - val_loss: 0.3573 - val_loss/inference_loss: 0.3573
# Epoch 62/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3863 - loss/inference_loss: 0.3863 - val_loss: 0.3447 - val_loss/inference_loss: 0.3447
# Epoch 63/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3970 - loss/inference_loss: 0.3970 - val_loss: 0.3480 - val_loss/inference_loss: 0.3480
# Epoch 64/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3846 - loss/inference_loss: 0.3846 - val_loss: 0.3741 - val_loss/inference_loss: 0.3741
# Epoch 65/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3826 - loss/inference_loss: 0.3826 - val_loss: 0.4275 - val_loss/inference_loss: 0.4275
# Epoch 66/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3922 - loss/inference_loss: 0.3922 - val_loss: 0.4731 - val_loss/inference_loss: 0.4731
# Epoch 67/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3926 - loss/inference_loss: 0.3926 - val_loss: 0.3786 - val_loss/inference_loss: 0.3786
# Epoch 68/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3860 - loss/inference_loss: 0.3860 - val_loss: 0.4138 - val_loss/inference_loss: 0.4138
# Epoch 69/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3833 - loss/inference_loss: 0.3833 - val_loss: 0.5568 - val_loss/inference_loss: 0.5568
# Epoch 70/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3780 - loss/inference_loss: 0.3780 - val_loss: 0.4278 - val_loss/inference_loss: 0.4278
# Epoch 71/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3832 - loss/inference_loss: 0.3832 - val_loss: 0.3803 - val_loss/inference_loss: 0.3803
# Epoch 72/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3897 - loss/inference_loss: 0.3897 - val_loss: 0.5014 - val_loss/inference_loss: 0.5014
# Epoch 73/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3770 - loss/inference_loss: 0.3770 - val_loss: 0.2688 - val_loss/inference_loss: 0.2688
# Epoch 74/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3891 - loss/inference_loss: 0.3891 - val_loss: 0.3671 - val_loss/inference_loss: 0.3671
# Epoch 75/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3757 - loss/inference_loss: 0.3757 - val_loss: 0.3774 - val_loss/inference_loss: 0.3774
# Epoch 76/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3799 - loss/inference_loss: 0.3799 - val_loss: 0.3208 - val_loss/inference_loss: 0.3208
# Epoch 77/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3796 - loss/inference_loss: 0.3796 - val_loss: 0.3041 - val_loss/inference_loss: 0.3041
# Epoch 78/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3832 - loss/inference_loss: 0.3832 - val_loss: 0.3530 - val_loss/inference_loss: 0.3530
# Epoch 79/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3773 - loss/inference_loss: 0.3773 - val_loss: 0.3317 - val_loss/inference_loss: 0.3317
# Epoch 80/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3811 - loss/inference_loss: 0.3811 - val_loss: 0.3187 - val_loss/inference_loss: 0.3187
# Epoch 81/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3760 - loss/inference_loss: 0.3760 - val_loss: 0.3615 - val_loss/inference_loss: 0.3615
# Epoch 82/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3818 - loss/inference_loss: 0.3818 - val_loss: 0.5030 - val_loss/inference_loss: 0.5030
# Epoch 83/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3708 - loss/inference_loss: 0.3708 - val_loss: 0.4664 - val_loss/inference_loss: 0.4664
# Epoch 84/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3795 - loss/inference_loss: 0.3795 - val_loss: 0.2955 - val_loss/inference_loss: 0.2955
# Epoch 85/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3744 - loss/inference_loss: 0.3744 - val_loss: 0.3569 - val_loss/inference_loss: 0.3569
# Epoch 86/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3744 - loss/inference_loss: 0.3744 - val_loss: 0.5180 - val_loss/inference_loss: 0.5180
# Epoch 87/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3771 - loss/inference_loss: 0.3771 - val_loss: 0.3034 - val_loss/inference_loss: 0.3034
# Epoch 88/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3777 - loss/inference_loss: 0.3777 - val_loss: 0.4158 - val_loss/inference_loss: 0.4158
# Epoch 89/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3656 - loss/inference_loss: 0.3656 - val_loss: 0.3690 - val_loss/inference_loss: 0.3690
# Epoch 90/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3762 - loss/inference_loss: 0.3762 - val_loss: 0.2885 - val_loss/inference_loss: 0.2885
# Epoch 91/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3877 - loss/inference_loss: 0.3877 - val_loss: 0.2785 - val_loss/inference_loss: 0.2785
# Epoch 92/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3817 - loss/inference_loss: 0.3817 - val_loss: 0.3518 - val_loss/inference_loss: 0.3518
# Epoch 93/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3620 - loss/inference_loss: 0.3620 - val_loss: 0.3605 - val_loss/inference_loss: 0.3605
# Epoch 94/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3730 - loss/inference_loss: 0.3730 - val_loss: 0.4367 - val_loss/inference_loss: 0.4367
# Epoch 95/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3698 - loss/inference_loss: 0.3698 - val_loss: 0.4446 - val_loss/inference_loss: 0.4446
# Epoch 96/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3798 - loss/inference_loss: 0.3798 - val_loss: 0.4991 - val_loss/inference_loss: 0.4991
# Epoch 97/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3635 - loss/inference_loss: 0.3635 - val_loss: 0.3292 - val_loss/inference_loss: 0.3292
# Epoch 98/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3761 - loss/inference_loss: 0.3761 - val_loss: 0.3593 - val_loss/inference_loss: 0.3593
# Epoch 99/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3776 - loss/inference_loss: 0.3776 - val_loss: 0.4693 - val_loss/inference_loss: 0.4693
# Epoch 100/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3691 - loss/inference_loss: 0.3691 - val_loss: 0.4096 - val_loss/inference_loss: 0.4096
# Epoch 101/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3695 - loss/inference_loss: 0.3695 - val_loss: 0.3228 - val_loss/inference_loss: 0.3228
# Epoch 102/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3669 - loss/inference_loss: 0.3669 - val_loss: 0.4364 - val_loss/inference_loss: 0.4364
# Epoch 103/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3661 - loss/inference_loss: 0.3661 - val_loss: 0.3955 - val_loss/inference_loss: 0.3955
# Epoch 104/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3685 - loss/inference_loss: 0.3685 - val_loss: 0.4405 - val_loss/inference_loss: 0.4405
# Epoch 105/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3816 - loss/inference_loss: 0.3816 - val_loss: 0.4823 - val_loss/inference_loss: 0.4823
# Epoch 106/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3794 - loss/inference_loss: 0.3794 - val_loss: 0.4821 - val_loss/inference_loss: 0.4821
# Epoch 107/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3708 - loss/inference_loss: 0.3708 - val_loss: 0.3256 - val_loss/inference_loss: 0.3256
# Epoch 108/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3649 - loss/inference_loss: 0.3649 - val_loss: 0.3751 - val_loss/inference_loss: 0.3751
# Epoch 109/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3702 - loss/inference_loss: 0.3702 - val_loss: 0.3996 - val_loss/inference_loss: 0.3996
# Epoch 110/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3652 - loss/inference_loss: 0.3652 - val_loss: 0.4168 - val_loss/inference_loss: 0.4168
# Epoch 111/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3661 - loss/inference_loss: 0.3661 - val_loss: 0.3969 - val_loss/inference_loss: 0.3969
# Epoch 112/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3617 - loss/inference_loss: 0.3617 - val_loss: 0.4327 - val_loss/inference_loss: 0.4327
# Epoch 113/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3590 - loss/inference_loss: 0.3590 - val_loss: 0.3597 - val_loss/inference_loss: 0.3597
# Epoch 114/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3756 - loss/inference_loss: 0.3756 - val_loss: 0.3631 - val_loss/inference_loss: 0.3631
# Epoch 115/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3672 - loss/inference_loss: 0.3672 - val_loss: 0.3266 - val_loss/inference_loss: 0.3266
# Epoch 116/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3651 - loss/inference_loss: 0.3651 - val_loss: 0.2912 - val_loss/inference_loss: 0.2912
# Epoch 117/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3579 - loss/inference_loss: 0.3579 - val_loss: 0.4101 - val_loss/inference_loss: 0.4101
# Epoch 118/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3570 - loss/inference_loss: 0.3570 - val_loss: 0.3956 - val_loss/inference_loss: 0.3956
# Epoch 119/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3627 - loss/inference_loss: 0.3627 - val_loss: 0.2563 - val_loss/inference_loss: 0.2563
# Epoch 120/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3680 - loss/inference_loss: 0.3680 - val_loss: 0.3794 - val_loss/inference_loss: 0.3794
# Epoch 121/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3728 - loss/inference_loss: 0.3728 - val_loss: 0.3088 - val_loss/inference_loss: 0.3088
# Epoch 122/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3658 - loss/inference_loss: 0.3658 - val_loss: 0.3549 - val_loss/inference_loss: 0.3549
# Epoch 123/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3682 - loss/inference_loss: 0.3682 - val_loss: 0.3914 - val_loss/inference_loss: 0.3914
# Epoch 124/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3776 - loss/inference_loss: 0.3776 - val_loss: 0.3107 - val_loss/inference_loss: 0.3107
# Epoch 125/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3617 - loss/inference_loss: 0.3617 - val_loss: 0.3460 - val_loss/inference_loss: 0.3460
# Epoch 126/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3654 - loss/inference_loss: 0.3654 - val_loss: 0.3522 - val_loss/inference_loss: 0.3522
# Epoch 127/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3497 - loss/inference_loss: 0.3497 - val_loss: 0.5293 - val_loss/inference_loss: 0.5293
# Epoch 128/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3650 - loss/inference_loss: 0.3650 - val_loss: 0.3598 - val_loss/inference_loss: 0.3598
# Epoch 129/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3674 - loss/inference_loss: 0.3674 - val_loss: 0.4082 - val_loss/inference_loss: 0.4082
# Epoch 130/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3459 - loss/inference_loss: 0.3459 - val_loss: 0.3731 - val_loss/inference_loss: 0.3731
# Epoch 131/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3609 - loss/inference_loss: 0.3609 - val_loss: 0.3444 - val_loss/inference_loss: 0.3444
# Epoch 132/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3499 - loss/inference_loss: 0.3499 - val_loss: 0.2991 - val_loss/inference_loss: 0.2991
# Epoch 133/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3520 - loss/inference_loss: 0.3520 - val_loss: 0.4166 - val_loss/inference_loss: 0.4166
# Epoch 134/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3566 - loss/inference_loss: 0.3566 - val_loss: 0.4508 - val_loss/inference_loss: 0.4508
# Epoch 135/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3512 - loss/inference_loss: 0.3512 - val_loss: 0.3893 - val_loss/inference_loss: 0.3893
# Epoch 136/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3552 - loss/inference_loss: 0.3552 - val_loss: 0.4699 - val_loss/inference_loss: 0.4699
# Epoch 137/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3594 - loss/inference_loss: 0.3594 - val_loss: 0.4570 - val_loss/inference_loss: 0.4570
# Epoch 138/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3545 - loss/inference_loss: 0.3545 - val_loss: 0.3113 - val_loss/inference_loss: 0.3113
# Epoch 139/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3702 - loss/inference_loss: 0.3702 - val_loss: 0.3899 - val_loss/inference_loss: 0.3899
# Epoch 140/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3593 - loss/inference_loss: 0.3593 - val_loss: 0.4258 - val_loss/inference_loss: 0.4258
# Epoch 141/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3602 - loss/inference_loss: 0.3602 - val_loss: 0.3879 - val_loss/inference_loss: 0.3879
# Epoch 142/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3631 - loss/inference_loss: 0.3631 - val_loss: 0.3555 - val_loss/inference_loss: 0.3555
# Epoch 143/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3542 - loss/inference_loss: 0.3542 - val_loss: 0.3517 - val_loss/inference_loss: 0.3517
# Epoch 144/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3628 - loss/inference_loss: 0.3628 - val_loss: 0.4468 - val_loss/inference_loss: 0.4468
# Epoch 145/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3546 - loss/inference_loss: 0.3546 - val_loss: 0.4038 - val_loss/inference_loss: 0.4038
# Epoch 146/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3602 - loss/inference_loss: 0.3602 - val_loss: 0.4280 - val_loss/inference_loss: 0.4280
# Epoch 147/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3519 - loss/inference_loss: 0.3519 - val_loss: 0.3645 - val_loss/inference_loss: 0.3645
# Epoch 148/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3603 - loss/inference_loss: 0.3603 - val_loss: 0.3592 - val_loss/inference_loss: 0.3592
# Epoch 149/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3450 - loss/inference_loss: 0.3450 - val_loss: 0.4206 - val_loss/inference_loss: 0.4206
# Epoch 150/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3591 - loss/inference_loss: 0.3591 - val_loss: 0.3387 - val_loss/inference_loss: 0.3387
# Epoch 151/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3498 - loss/inference_loss: 0.3498 - val_loss: 0.5353 - val_loss/inference_loss: 0.5353
# Epoch 152/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3588 - loss/inference_loss: 0.3588 - val_loss: 0.2702 - val_loss/inference_loss: 0.2702
# Epoch 153/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3613 - loss/inference_loss: 0.3613 - val_loss: 0.4446 - val_loss/inference_loss: 0.4446
# Epoch 154/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3457 - loss/inference_loss: 0.3457 - val_loss: 0.5298 - val_loss/inference_loss: 0.5298
# Epoch 155/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3545 - loss/inference_loss: 0.3545 - val_loss: 0.3751 - val_loss/inference_loss: 0.3751
# Epoch 156/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3578 - loss/inference_loss: 0.3578 - val_loss: 0.3646 - val_loss/inference_loss: 0.3646
# Epoch 157/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3534 - loss/inference_loss: 0.3534 - val_loss: 0.2380 - val_loss/inference_loss: 0.2380
# Epoch 158/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3550 - loss/inference_loss: 0.3550 - val_loss: 0.2651 - val_loss/inference_loss: 0.2651
# Epoch 159/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3505 - loss/inference_loss: 0.3505 - val_loss: 0.2836 - val_loss/inference_loss: 0.2836
# Epoch 160/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3442 - loss/inference_loss: 0.3442 - val_loss: 0.3495 - val_loss/inference_loss: 0.3495
# Epoch 161/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3479 - loss/inference_loss: 0.3479 - val_loss: 0.2657 - val_loss/inference_loss: 0.2657
# Epoch 162/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3372 - loss/inference_loss: 0.3372 - val_loss: 0.3824 - val_loss/inference_loss: 0.3824
# Epoch 163/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3477 - loss/inference_loss: 0.3477 - val_loss: 0.2510 - val_loss/inference_loss: 0.2510
# Epoch 164/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3475 - loss/inference_loss: 0.3475 - val_loss: 0.4408 - val_loss/inference_loss: 0.4408
# Epoch 165/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3434 - loss/inference_loss: 0.3434 - val_loss: 0.3660 - val_loss/inference_loss: 0.3660
# Epoch 166/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3478 - loss/inference_loss: 0.3478 - val_loss: 0.4102 - val_loss/inference_loss: 0.4102
# Epoch 167/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3566 - loss/inference_loss: 0.3566 - val_loss: 0.3030 - val_loss/inference_loss: 0.3030
# Epoch 168/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3430 - loss/inference_loss: 0.3430 - val_loss: 0.3350 - val_loss/inference_loss: 0.3350
# Epoch 169/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3447 - loss/inference_loss: 0.3447 - val_loss: 0.2731 - val_loss/inference_loss: 0.2731
# Epoch 170/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3577 - loss/inference_loss: 0.3577 - val_loss: 0.2958 - val_loss/inference_loss: 0.2958
# Epoch 171/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3608 - loss/inference_loss: 0.3608 - val_loss: 0.4357 - val_loss/inference_loss: 0.4357
# Epoch 172/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3487 - loss/inference_loss: 0.3487 - val_loss: 0.3754 - val_loss/inference_loss: 0.3754
# Epoch 173/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3453 - loss/inference_loss: 0.3453 - val_loss: 0.4711 - val_loss/inference_loss: 0.4711
# Epoch 174/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3392 - loss/inference_loss: 0.3392 - val_loss: 0.3952 - val_loss/inference_loss: 0.3952
# Epoch 175/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3412 - loss/inference_loss: 0.3412 - val_loss: 0.3398 - val_loss/inference_loss: 0.3398
# Epoch 176/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3495 - loss/inference_loss: 0.3495 - val_loss: 0.4672 - val_loss/inference_loss: 0.4672
# Epoch 177/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3429 - loss/inference_loss: 0.3429 - val_loss: 0.3623 - val_loss/inference_loss: 0.3623
# Epoch 178/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3471 - loss/inference_loss: 0.3471 - val_loss: 0.4445 - val_loss/inference_loss: 0.4445
# Epoch 179/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3353 - loss/inference_loss: 0.3353 - val_loss: 0.3043 - val_loss/inference_loss: 0.3043
# Epoch 180/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3438 - loss/inference_loss: 0.3438 - val_loss: 0.3530 - val_loss/inference_loss: 0.3530
# Epoch 181/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3480 - loss/inference_loss: 0.3480 - val_loss: 0.3531 - val_loss/inference_loss: 0.3531
# Epoch 182/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3456 - loss/inference_loss: 0.3456 - val_loss: 0.2667 - val_loss/inference_loss: 0.2667
# Epoch 183/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3357 - loss/inference_loss: 0.3357 - val_loss: 0.3635 - val_loss/inference_loss: 0.3635
# Epoch 184/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3397 - loss/inference_loss: 0.3397 - val_loss: 0.3003 - val_loss/inference_loss: 0.3003
# Epoch 185/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3402 - loss/inference_loss: 0.3402 - val_loss: 0.2943 - val_loss/inference_loss: 0.2943
# Epoch 186/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3415 - loss/inference_loss: 0.3415 - val_loss: 0.2789 - val_loss/inference_loss: 0.2789
# Epoch 187/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3321 - loss/inference_loss: 0.3321 - val_loss: 0.4036 - val_loss/inference_loss: 0.4036
# Epoch 188/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3409 - loss/inference_loss: 0.3409 - val_loss: 0.4252 - val_loss/inference_loss: 0.4252
# Epoch 189/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3407 - loss/inference_loss: 0.3407 - val_loss: 0.5048 - val_loss/inference_loss: 0.5048
# Epoch 190/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3438 - loss/inference_loss: 0.3438 - val_loss: 0.3730 - val_loss/inference_loss: 0.3730
# Epoch 191/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3404 - loss/inference_loss: 0.3404 - val_loss: 0.3900 - val_loss/inference_loss: 0.3900
# Epoch 192/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3347 - loss/inference_loss: 0.3347 - val_loss: 0.4753 - val_loss/inference_loss: 0.4753
# Epoch 193/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3364 - loss/inference_loss: 0.3364 - val_loss: 0.3680 - val_loss/inference_loss: 0.3680
# Epoch 194/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3463 - loss/inference_loss: 0.3463 - val_loss: 0.3747 - val_loss/inference_loss: 0.3747
# Epoch 195/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3451 - loss/inference_loss: 0.3451 - val_loss: 0.2572 - val_loss/inference_loss: 0.2572
# Epoch 196/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3423 - loss/inference_loss: 0.3423 - val_loss: 0.3407 - val_loss/inference_loss: 0.3407
# Epoch 197/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3416 - loss/inference_loss: 0.3416 - val_loss: 0.3621 - val_loss/inference_loss: 0.3621
# Epoch 198/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3483 - loss/inference_loss: 0.3483 - val_loss: 0.3515 - val_loss/inference_loss: 0.3515
# Epoch 199/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3417 - loss/inference_loss: 0.3417 - val_loss: 0.3564 - val_loss/inference_loss: 0.3564
# Epoch 200/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3562 - loss/inference_loss: 0.3562 - val_loss: 0.3227 - val_loss/inference_loss: 0.3227
# Epoch 201/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3463 - loss/inference_loss: 0.3463 - val_loss: 0.3667 - val_loss/inference_loss: 0.3667
# Epoch 202/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3390 - loss/inference_loss: 0.3390 - val_loss: 0.4085 - val_loss/inference_loss: 0.4085
# Epoch 203/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3409 - loss/inference_loss: 0.3409 - val_loss: 0.3570 - val_loss/inference_loss: 0.3570
# Epoch 204/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3370 - loss/inference_loss: 0.3370 - val_loss: 0.2651 - val_loss/inference_loss: 0.2651
# Epoch 205/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3460 - loss/inference_loss: 0.3460 - val_loss: 0.3082 - val_loss/inference_loss: 0.3082
# Epoch 206/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3360 - loss/inference_loss: 0.3360 - val_loss: 0.3823 - val_loss/inference_loss: 0.3823
# Epoch 207/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3475 - loss/inference_loss: 0.3475 - val_loss: 0.3707 - val_loss/inference_loss: 0.3707
# Epoch 208/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3317 - loss/inference_loss: 0.3317 - val_loss: 0.2831 - val_loss/inference_loss: 0.2831
# Epoch 209/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3432 - loss/inference_loss: 0.3432 - val_loss: 0.2918 - val_loss/inference_loss: 0.2918
# Epoch 210/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3453 - loss/inference_loss: 0.3453 - val_loss: 0.3853 - val_loss/inference_loss: 0.3853
# Epoch 211/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3386 - loss/inference_loss: 0.3386 - val_loss: 0.3197 - val_loss/inference_loss: 0.3197
# Epoch 212/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3333 - loss/inference_loss: 0.3333 - val_loss: 0.4060 - val_loss/inference_loss: 0.4060
# Epoch 213/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3351 - loss/inference_loss: 0.3351 - val_loss: 0.3042 - val_loss/inference_loss: 0.3042
# Epoch 214/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3385 - loss/inference_loss: 0.3385 - val_loss: 0.3576 - val_loss/inference_loss: 0.3576
# Epoch 215/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3331 - loss/inference_loss: 0.3331 - val_loss: 0.3942 - val_loss/inference_loss: 0.3942
# Epoch 216/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3465 - loss/inference_loss: 0.3465 - val_loss: 0.3568 - val_loss/inference_loss: 0.3568
# Epoch 217/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3401 - loss/inference_loss: 0.3401 - val_loss: 0.3491 - val_loss/inference_loss: 0.3491
# Epoch 218/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3377 - loss/inference_loss: 0.3377 - val_loss: 0.3094 - val_loss/inference_loss: 0.3094
# Epoch 219/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3439 - loss/inference_loss: 0.3439 - val_loss: 0.4395 - val_loss/inference_loss: 0.4395
# Epoch 220/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3385 - loss/inference_loss: 0.3385 - val_loss: 0.2886 - val_loss/inference_loss: 0.2886
# Epoch 221/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3419 - loss/inference_loss: 0.3419 - val_loss: 0.3820 - val_loss/inference_loss: 0.3820
# Epoch 222/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3491 - loss/inference_loss: 0.3491 - val_loss: 0.3056 - val_loss/inference_loss: 0.3056
# Epoch 223/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3324 - loss/inference_loss: 0.3324 - val_loss: 0.4542 - val_loss/inference_loss: 0.4542
# Epoch 224/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3390 - loss/inference_loss: 0.3390 - val_loss: 0.2799 - val_loss/inference_loss: 0.2799
# Epoch 225/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3473 - loss/inference_loss: 0.3473 - val_loss: 0.2123 - val_loss/inference_loss: 0.2123
# Epoch 226/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3382 - loss/inference_loss: 0.3382 - val_loss: 0.5258 - val_loss/inference_loss: 0.5258
# Epoch 227/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3377 - loss/inference_loss: 0.3377 - val_loss: 0.5145 - val_loss/inference_loss: 0.5145
# Epoch 228/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3287 - loss/inference_loss: 0.3287 - val_loss: 0.2734 - val_loss/inference_loss: 0.2734
# Epoch 229/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3420 - loss/inference_loss: 0.3420 - val_loss: 0.3387 - val_loss/inference_loss: 0.3387
# Epoch 230/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3285 - loss/inference_loss: 0.3285 - val_loss: 0.3767 - val_loss/inference_loss: 0.3767
# Epoch 231/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3321 - loss/inference_loss: 0.3321 - val_loss: 0.3790 - val_loss/inference_loss: 0.3790
# Epoch 232/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3252 - loss/inference_loss: 0.3252 - val_loss: 0.3383 - val_loss/inference_loss: 0.3383
# Epoch 233/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3216 - loss/inference_loss: 0.3216 - val_loss: 0.4076 - val_loss/inference_loss: 0.4076
# Epoch 234/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3309 - loss/inference_loss: 0.3309 - val_loss: 0.4085 - val_loss/inference_loss: 0.4085
# Epoch 235/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3374 - loss/inference_loss: 0.3374 - val_loss: 0.2849 - val_loss/inference_loss: 0.2849
# Epoch 236/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3308 - loss/inference_loss: 0.3308 - val_loss: 0.4087 - val_loss/inference_loss: 0.4087
# Epoch 237/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3397 - loss/inference_loss: 0.3397 - val_loss: 0.3641 - val_loss/inference_loss: 0.3641
# Epoch 238/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3392 - loss/inference_loss: 0.3392 - val_loss: 0.4211 - val_loss/inference_loss: 0.4211
# Epoch 239/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3431 - loss/inference_loss: 0.3431 - val_loss: 0.2453 - val_loss/inference_loss: 0.2453
# Epoch 240/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3346 - loss/inference_loss: 0.3346 - val_loss: 0.3235 - val_loss/inference_loss: 0.3235
# Epoch 241/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3494 - loss/inference_loss: 0.3494 - val_loss: 0.3439 - val_loss/inference_loss: 0.3439
# Epoch 242/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3337 - loss/inference_loss: 0.3337 - val_loss: 0.2993 - val_loss/inference_loss: 0.2993
# Epoch 243/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3353 - loss/inference_loss: 0.3353 - val_loss: 0.3747 - val_loss/inference_loss: 0.3747
# Epoch 244/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3370 - loss/inference_loss: 0.3370 - val_loss: 0.3411 - val_loss/inference_loss: 0.3411
# Epoch 245/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3426 - loss/inference_loss: 0.3426 - val_loss: 0.4120 - val_loss/inference_loss: 0.4120
# Epoch 246/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3304 - loss/inference_loss: 0.3304 - val_loss: 0.4562 - val_loss/inference_loss: 0.4562
# Epoch 247/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3290 - loss/inference_loss: 0.3290 - val_loss: 0.4425 - val_loss/inference_loss: 0.4425
# Epoch 248/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3312 - loss/inference_loss: 0.3312 - val_loss: 0.3563 - val_loss/inference_loss: 0.3563
# Epoch 249/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3382 - loss/inference_loss: 0.3382 - val_loss: 0.3244 - val_loss/inference_loss: 0.3244
# Epoch 250/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3329 - loss/inference_loss: 0.3329 - val_loss: 0.3293 - val_loss/inference_loss: 0.3293
# Epoch 251/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3297 - loss/inference_loss: 0.3297 - val_loss: 0.3970 - val_loss/inference_loss: 0.3970
# Epoch 252/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3307 - loss/inference_loss: 0.3307 - val_loss: 0.3081 - val_loss/inference_loss: 0.3081
# Epoch 253/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3287 - loss/inference_loss: 0.3287 - val_loss: 0.4677 - val_loss/inference_loss: 0.4677
# Epoch 254/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3396 - loss/inference_loss: 0.3396 - val_loss: 0.4377 - val_loss/inference_loss: 0.4377
# Epoch 255/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3290 - loss/inference_loss: 0.3290 - val_loss: 0.4101 - val_loss/inference_loss: 0.4101
# Epoch 256/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3356 - loss/inference_loss: 0.3356 - val_loss: 0.4586 - val_loss/inference_loss: 0.4586
# Epoch 257/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3260 - loss/inference_loss: 0.3260 - val_loss: 0.3015 - val_loss/inference_loss: 0.3015
# Epoch 258/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3345 - loss/inference_loss: 0.3345 - val_loss: 0.3595 - val_loss/inference_loss: 0.3595
# Epoch 259/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3287 - loss/inference_loss: 0.3287 - val_loss: 0.4030 - val_loss/inference_loss: 0.4030
# Epoch 260/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3302 - loss/inference_loss: 0.3302 - val_loss: 0.3613 - val_loss/inference_loss: 0.3613
# Epoch 261/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3390 - loss/inference_loss: 0.3390 - val_loss: 0.3039 - val_loss/inference_loss: 0.3039
# Epoch 262/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3316 - loss/inference_loss: 0.3316 - val_loss: 0.4288 - val_loss/inference_loss: 0.4288
# Epoch 263/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3325 - loss/inference_loss: 0.3325 - val_loss: 0.2401 - val_loss/inference_loss: 0.2401
# Epoch 264/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3333 - loss/inference_loss: 0.3333 - val_loss: 0.2904 - val_loss/inference_loss: 0.2904
# Epoch 265/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3317 - loss/inference_loss: 0.3317 - val_loss: 0.3717 - val_loss/inference_loss: 0.3717
# Epoch 266/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3302 - loss/inference_loss: 0.3302 - val_loss: 0.3338 - val_loss/inference_loss: 0.3338
# Epoch 267/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3353 - loss/inference_loss: 0.3353 - val_loss: 0.2931 - val_loss/inference_loss: 0.2931
# Epoch 268/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3261 - loss/inference_loss: 0.3261 - val_loss: 0.3257 - val_loss/inference_loss: 0.3257
# Epoch 269/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3372 - loss/inference_loss: 0.3372 - val_loss: 0.2902 - val_loss/inference_loss: 0.2902
# Epoch 270/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3268 - loss/inference_loss: 0.3268 - val_loss: 0.3162 - val_loss/inference_loss: 0.3162
# Epoch 271/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3298 - loss/inference_loss: 0.3298 - val_loss: 0.3691 - val_loss/inference_loss: 0.3691
# Epoch 272/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3286 - loss/inference_loss: 0.3286 - val_loss: 0.2861 - val_loss/inference_loss: 0.2861
# Epoch 273/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3315 - loss/inference_loss: 0.3315 - val_loss: 0.3659 - val_loss/inference_loss: 0.3659
# Epoch 274/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3234 - loss/inference_loss: 0.3234 - val_loss: 0.3359 - val_loss/inference_loss: 0.3359
# Epoch 275/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3265 - loss/inference_loss: 0.3265 - val_loss: 0.3293 - val_loss/inference_loss: 0.3293
# Epoch 276/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3246 - loss/inference_loss: 0.3246 - val_loss: 0.2681 - val_loss/inference_loss: 0.2681
# Epoch 277/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3286 - loss/inference_loss: 0.3286 - val_loss: 0.4214 - val_loss/inference_loss: 0.4214
# Epoch 278/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3290 - loss/inference_loss: 0.3290 - val_loss: 0.3532 - val_loss/inference_loss: 0.3532
# Epoch 279/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3306 - loss/inference_loss: 0.3306 - val_loss: 0.4328 - val_loss/inference_loss: 0.4328
# Epoch 280/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3221 - loss/inference_loss: 0.3221 - val_loss: 0.3477 - val_loss/inference_loss: 0.3477
# Epoch 281/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3269 - loss/inference_loss: 0.3269 - val_loss: 0.5191 - val_loss/inference_loss: 0.5191
# Epoch 282/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3369 - loss/inference_loss: 0.3369 - val_loss: 0.4677 - val_loss/inference_loss: 0.4677
# Epoch 283/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3362 - loss/inference_loss: 0.3362 - val_loss: 0.3530 - val_loss/inference_loss: 0.3530
# Epoch 284/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3318 - loss/inference_loss: 0.3318 - val_loss: 0.3049 - val_loss/inference_loss: 0.3049
# Epoch 285/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3365 - loss/inference_loss: 0.3365 - val_loss: 0.4124 - val_loss/inference_loss: 0.4124
# Epoch 286/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3254 - loss/inference_loss: 0.3254 - val_loss: 0.3639 - val_loss/inference_loss: 0.3639
# Epoch 287/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3346 - loss/inference_loss: 0.3346 - val_loss: 0.2972 - val_loss/inference_loss: 0.2972
# Epoch 288/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3316 - loss/inference_loss: 0.3316 - val_loss: 0.3194 - val_loss/inference_loss: 0.3194
# Epoch 289/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3301 - loss/inference_loss: 0.3301 - val_loss: 0.3186 - val_loss/inference_loss: 0.3186
# Epoch 290/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3456 - loss/inference_loss: 0.3456 - val_loss: 0.4440 - val_loss/inference_loss: 0.4440
# Epoch 291/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3264 - loss/inference_loss: 0.3264 - val_loss: 0.2994 - val_loss/inference_loss: 0.2994
# Epoch 292/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3307 - loss/inference_loss: 0.3307 - val_loss: 0.3191 - val_loss/inference_loss: 0.3191
# Epoch 293/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3342 - loss/inference_loss: 0.3342 - val_loss: 0.3452 - val_loss/inference_loss: 0.3452
# Epoch 294/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3212 - loss/inference_loss: 0.3212 - val_loss: 0.2443 - val_loss/inference_loss: 0.2443
# Epoch 295/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3237 - loss/inference_loss: 0.3237 - val_loss: 0.3970 - val_loss/inference_loss: 0.3970
# Epoch 296/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3270 - loss/inference_loss: 0.3270 - val_loss: 0.3098 - val_loss/inference_loss: 0.3098
# Epoch 297/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3338 - loss/inference_loss: 0.3338 - val_loss: 0.4099 - val_loss/inference_loss: 0.4099
# Epoch 298/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3324 - loss/inference_loss: 0.3324 - val_loss: 0.2775 - val_loss/inference_loss: 0.2775
# Epoch 299/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3276 - loss/inference_loss: 0.3276 - val_loss: 0.3954 - val_loss/inference_loss: 0.3954
# Epoch 300/300
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3295 - loss/inference_loss: 0.3295 - val_loss: 0.2278 - val_loss/inference_loss: 0.2278

# %% [markdown]
# ### Inspecting the Loss <a class="anchor" id="inspecting_the_loss"></a>
#
# Following our online simulation-based training, we can quickly visualize the loss trajectory using the `plots.loss` function from the `diagnostics` module.

# %%
f = bf.diagnostics.plots.loss(history)

# %% [markdown]
# Great, it seems that our approximator has converged! Before we get too excited and throw our networks at real data, we need to make sure that they meet our expectations <em>in silico</em>, that is, given the small world of simulations the networks have seen during training.

# %% [markdown]
# ## Validation Phase <a class="anchor" id="validation_phase"></a>
#
# When it comes to validating the posterior samples, we can either deploy manual diagnostics from the `diagnostics` module, or use the automated functions from the workflow. First, we demonstrate manual validation.

# %% [markdown]
# ### Manual Diagnositcs

# %%
# Set the number of posterior draws you want to get
num_samples = 1000

# Simulate 300 scenarios and extract time series from dict
test_sims = simulator.sample(300)
time_series = test_sims.pop("cases")

# Obtain 1000 samples (~20 seconds due to multi-step sampling via FlowMatching)
samples = workflow.sample(conditions={"cases": time_series}, num_samples=num_samples)

# %% [markdown]
# ### Simulation-Based Calibration - Rank Histograms <a class="anchor" id="simulation_based_calibration__"></a>
#
# As a further <strong>small world</strong> (i.e., before real data) sanity check, we can also test the calibration of the amortizer through simulation-based calibration (SBC). See the corresponding paper for more details (https://arxiv.org/pdf/1804.06788.pdf). Accordingly, we expect to observe approximately uniform rank statistic histograms. In the present case, this is indeed what we get:

# %%
f = bf.diagnostics.plots.calibration_histogram(samples, test_sims)
# Out:
# WARNING:bayesflow:The ratio of simulations / posterior draws should be > 20 for reliable variance reduction, but your ratio is 0. Confidence intervals might be unreliable!

# %% [markdown]
# ### Simulation-Based Calibration - Rank ECDF <a class="anchor" id="simulation_based_calibration___0"></a>
#
# For models with many parameters, inspecting many histograms can become unwieldly. Moreover, the `num_bins` hyperparameter for the construction of SBC rank histograms can be hard to choose. An alternative diagnostic approach for calibration is through empirical cumulative distribution functions (ECDF) of rank statistics. You can read more about this approach in the corresponding paper (https://arxiv.org/abs/2103.10522).
#
# In order to inspect the ECDFs of marginal distributions, we will simulate $300$ new pairs of simulated data and generating parameters $(\boldsymbol{x}, \boldsymbol{\theta})$ and use the function `plots.calibration_ecdf` from the `diagnostics` module:

# %%
f = bf.diagnostics.plots.calibration_ecdf(samples, test_sims, difference=True)

# %% [markdown]
# ### Inferential Adequacy (Global) <a class="anchor" id="inferential_adequacy__global_"></a>
#
# Depending on the application, it might be interesting to see how well summaries of the full posterior (e.g., means, medians) recover the assumed true parameter values. We can test this <em>in silico</em> via the `plots.recovery` function in the `diagnostics` module. For instance, we can compare how well posterior means recover the true parameter (i.e., posterior z-score, https://betanalpha.github.io/assets/case_studies/principled_bayesian_workflow.html). Below, we re-use the $300$ simulations we took for computing the rank ECDFs, but obtain a larger number of posterior draws per data set for more stable results:

# %%
f = bf.diagnostics.plots.recovery(samples, test_sims)

# %% [markdown]
# Interestingly, it seems that the parameters $\theta_1 = \mu$ and $\theta_2 = D$ have not been learned properly as they are estimated roughly the same for every simulated datset used during testing. For some models, this might indicate that the the network training had partially failed; and we would have to train longer or adjust the network architecture. For this specific model, however, the reason is different: From the provided observables, these parameters are actually not identified so cannot be learned consistently, no matter the kind of approximator we would use.

# %% [markdown]
# ### Automatic Diagnostics
#
# The basic workflow object wraps together a bunch of useful functions that can be called automatically. For instance, we can easily obtain numerical error estimates for the big, NRMSE, posterior contraction, and calibration, for $300$ new data sets:

# %%
metrics = workflow.compute_diagnostics(test_data=300)
metrics
# Out:
#                           lambd        mu         D        I0       psi
# NRMSE                  0.062842  0.214756  0.192316  0.198157  0.153797
# Posterior Contraction  0.955754  0.161383  0.254078  0.506163  0.870388
# Calibration Error      0.013772  0.027105  0.012544  0.008684  0.010877

# %% [markdown]
# We can also obtain the full set of graphical diagnostics:

# %%
figures = workflow.plot_diagnostics(
    test_data=300,
    loss_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    recovery_kwargs={"figsize": (15, 3), "label_fontsize": 12},
    calibration_ecdf_kwargs={"figsize": (15, 3), "legend_fontsize": 8, "difference": True, "label_fontsize": 12},
    z_score_contraction_kwargs={"figsize": (15, 3), "label_fontsize": 12}    
)

# %% [markdown]
# ## Inference Phase <a class="anchor" id="inference_phase"></a>
#
# We can now move on to using real data. This is easy, and since we are using an adapter, the same transformations applied during training will be applied during the inference phase.

# %%
# Our loader returns a 1D array
obs_cases = load_data()

# Note that we transform the 1D array into shape (1, T, 1), indicating one time series
samples = workflow.sample(conditions={"cases": obs_cases[None, :, None]}, num_samples=num_samples)

# Convert into a nice format
samples = pd.DataFrame(keras.tree.map_structure(np.squeeze, samples))
samples
# Out:
#         lambd        mu          D         I0        psi
# 0    0.403687  0.122163  10.466886   7.511261  10.168219
# 1    0.437258  0.157545   6.790879  24.728636   6.439188
# 2    0.331076  0.130523   9.015184  33.196869   8.155951
# 3    0.434405  0.121252  10.184278   6.120307   5.031815
# 4    0.439438  0.114410   6.731655  22.179955   5.312669
# ..        ...       ...        ...        ...        ...
# 995  0.436896  0.157343   8.640545  12.541692   6.210937
# 996  0.363623  0.129838   8.362200  26.399714   3.134787
# 997  0.387780  0.123220   8.844730  19.431730   3.366643
# 998  0.353423  0.100564   8.381845  22.692436  12.438321
# 999  0.398078  0.153104   5.633806  41.920860   5.277294
#
# [1000 rows x 5 columns]

# %% [markdown]
# ### Posterior Retrodictive Checks <a class="anchor" id="posterior_retrodictive_checks"></a>
#
# These are also called <em>posterior predictive checks</em>, but here we want to explicitly highlight the fact that we are not predicting future data but testing the <strong>generative performance</strong> or <strong>re-simulation performance</strong> of the model. In other words, we want to test how well the simulator can reproduce the actually observed data given the parameter posterior $p(\theta \mid x_{1:T})$.
#
# Here, we will create a custom function which plots the observed data and then overlays draws from the posterior predictive.

# %%
import matplotlib.pyplot as plt


def plot_ppc(samples, obs_cases, logscale=True, color="#132a70", dummy=True, figsize=(12, 6), font_size=18):
    """
    Helper function to perform some plotting of the posterior predictive.
    """
    # Plot settings
    plt.rcParams["font.size"] = font_size
    f, ax = plt.subplots(1, 1, figsize=figsize)
    T = len(obs_cases)

    # Re-simulations
    sims = []
    for i in range(samples.shape[0]):
        # Note - simulator returns 2D arrays of shape (T, 1), so we remove trailing dim
        sim_cases = stationary_SIR(*samples.values[i])
        sims.append(sim_cases["cases"][:, 0])
    sims = np.array(sims)

    # Compute quantiles for each t = 1,...,T
    qs_50 = np.quantile(sims, q=[0.25, 0.75], axis=0)
    qs_90 = np.quantile(sims, q=[0.05, 0.95], axis=0)
    qs_95 = np.quantile(sims, q=[0.025, 0.975], axis=0)

    # Plot median predictions and observed data
    ax.plot(np.median(sims, axis=0), label="Median predicted cases", color=color)
    ax.plot(obs_cases, marker="o", label="Reported cases", color="black", linestyle="dashed", alpha=0.8)

    # Add compatibility intervals (also called credible intervals)
    ax.fill_between(range(T), qs_50[0], qs_50[1], color=color, alpha=0.5, label="50% CI")
    ax.fill_between(range(T), qs_90[0], qs_90[1], color=color, alpha=0.3, label="90% CI")
    ax.fill_between(range(T), qs_95[0], qs_95[1], color=color, alpha=0.1, label="95% CI")

    # Grid and schmuck
    ax.grid(color="grey", linestyle="-", linewidth=0.25, alpha=0.5)
    ax.spines["right"].set_visible(False)
    ax.spines["top"].set_visible(False)
    ax.set_xlabel("Days since pandemic onset")
    ax.set_ylabel("Number of cases")
    ax.minorticks_off()
    if logscale:
        ax.set_yscale("log")
    ax.legend(fontsize=font_size)
    return f

# %% [markdown]
# We can now go on and plot the re-simulations:

# %%
f = plot_ppc(samples, obs_cases)

# %% [markdown]
# That's it for this tutorial! You now know how to use the basic building blocks of `BayesFlow` to create amortized neural approximators. :)
#
# <!-- In the [next tutorial](./PriorSensitivity_Covid19_Initial.ipynb), we will go through a <strong>prior sensitivity analysis</strong> with `BayesFlow`, which is as easy to perform as it is important for ascertaining the robustness of our inferences. -->
